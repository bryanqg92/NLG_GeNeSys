# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
# Cargar el dataset
data = pd.read_csv('/content/drive/MyDrive/UBA/Trabajo de grado/dataset_wide.csv')

  # Mostrar las primeras filas del dataset
print(data.head())
# Out:
#           P         D          L          R P_fuzzy_set  P_membership  \
# 0  0.045553  0.608390 -18.517306  67.099168          ok      0.886118
# 1 -0.979829  0.468399  62.832204  -7.498536   muy lejos      0.966382
# 2  0.968055  0.035674 -34.584612 -12.701870   muy cerca      0.946758
# 3  0.402764  0.032081 -71.360223  77.859054       cerca      0.995394
# 4 -0.503925  0.629578  61.566158  16.442472       lejos      0.826791
#
#    D_fuzzy_set  D_membership                  L_fuzzy_set  L_membership  \
# 0  acercandose      1.000000        muy lento hacia atrás      0.574135
# 1  acercandose      1.000000    rápidamente hacia delante      0.858390
# 2   sin cambio      0.821631        despacito hacia atrás      0.541539
# 3   sin cambio      0.839593  bastante rápido hacia atrás      0.784006
# 4  acercandose      1.000000    rápidamente hacia delante      0.921692
#
#                      R_fuzzy_set  R_membership  \
# 0      rápidamente hacia delante      0.645042
# 1          muy lento hacia atrás      0.874927
# 2          muy lento hacia atrás      0.864907
# 3  bastante rápido hacia delante      0.892953
# 4        muy lento hacia delante      0.677876
#
#                                                FRASE  CAT
# 0  en caso de que te estés acercando mientras est...    3
# 1  En caso de estar muy lejos de la pared y estás...    1
# 2  Cuando te encuentres muy cerca a la pared sin ...   10
# 3  Cuando estés cerca a la pared, pero ni te acer...    9
# 4  en caso de que te estes acercando al pared per...    2

# %%
X = data[['P','D','L','R','CAT','P_fuzzy_set', 'D_fuzzy_set', 'L_fuzzy_set', 'R_fuzzy_set']]
y = data['FRASE']
#z = data[['P_fuzzy_set', 'D_fuzzy_set', 'L_fuzzy_set', 'R_fuzzy_set']].apply(lambda x: ' '.join(x), axis=1)

# %%
with open('/content/drive/MyDrive/UBA/Trabajo de grado/corpus.txt', 'r') as f:
    text = f.readlines()
# Remueve los caracteres de salto de línea y los reemplaza por espacios en blanco
#text = text.replace('\n', ' ')

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()
tokenizer.fit_on_texts(text)
num_decoder_tokens = len(tokenizer.word_index) + 1

# %%
from sklearn.model_selection import train_test_split

# Dividir los datos en conjunto de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = data['CAT'], test_size=0.2, random_state=42)

# Dividir el conjunto de entrenamiento en conjunto de entrenamiento y validación
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)

'''
# Obtener el índice de las filas de X_train, X_val y X_test
idx_train = X_train.index
idx_val = X_val.index
idx_test = X_test.index
'''
# Out:
# '\n# Obtener el índice de las filas de X_train, X_val y X_test\nidx_train = X_train.index\nidx_val = X_val.index\nidx_test = X_test.index\n'

# %%
z_train = X_train[['P_fuzzy_set', 'D_fuzzy_set', 'L_fuzzy_set', 'R_fuzzy_set']].apply(lambda x: ' '.join(x), axis=1)
z_val = X_val[['P_fuzzy_set', 'D_fuzzy_set', 'L_fuzzy_set', 'R_fuzzy_set']].apply(lambda x: ' '.join(x), axis=1)
z_test = X_test[['P_fuzzy_set', 'D_fuzzy_set', 'L_fuzzy_set', 'R_fuzzy_set']].apply(lambda x: ' '.join(x), axis=1)

X_train = X_train[['P','D','L','R']].values
X_val = X_val[['P','D','L','R']].values
X_test = X_test[['P','D','L','R']].values

# %%
y_train_tokenized = tokenizer.texts_to_sequences(y_train)
y_val_tokenized = tokenizer.texts_to_sequences(y_val)
y_test_tokenized = tokenizer.texts_to_sequences(y_test)

# %%
z_train = tokenizer.texts_to_sequences(z_train)
z_val = tokenizer.texts_to_sequences(z_val)
z_test = tokenizer.texts_to_sequences(z_test)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_len = 40
y_train_tokenized = pad_sequences(y_train_tokenized, maxlen=max_len, padding='post', truncating='post')
y_val_tokenized = pad_sequences(y_val_tokenized, maxlen=max_len, padding='post', truncating='post')
y_test_tokenized = pad_sequences(y_test_tokenized, maxlen=max_len, padding='post', truncating='post')
z_train = pad_sequences(z_train, maxlen=max_len, padding='post', truncating='post')
z_val = pad_sequences(z_val, maxlen=max_len, padding='post', truncating='post')
z_test = pad_sequences(z_test, maxlen=max_len, padding='post', truncating='post')

# %%
y_train_tokenized = np.array(y_train_tokenized)
y_val_tokenized = np.array(y_val_tokenized)
y_test_tokenized = np.array(y_test_tokenized)
z_train =np.array(z_train)
z_val = np.array(z_val)
z_test = np.array(z_test)

# %%
from sklearn.preprocessing import StandardScaler

# Ajusta las columnas numéricas con StandardScaler
scaler_values = StandardScaler()

scaler_values.fit(data[['P','D','L','R']].values)
# Out:
# StandardScaler()

# %%
X_train_scaled = scaler_values.transform(X_train)
X_val_scaled =scaler_values.transform(X_val)
X_test_scaled =scaler_values.transform(X_test)

# %%
print('tamaño X train_scaled', X_train_scaled.shape)
print('tamaño y train', y_train_tokenized.shape)
print('tamaño z train', z_train.shape)


print('tamaño X val_scaled', X_val_scaled.shape)
print('tamaño y val', y_val_tokenized.shape)
print('tamaño z val_scaled', z_val.shape)

print('tamaño X test_scaled', X_test_scaled.shape)
print('tamaño y test', y_test_tokenized.shape)
print('tamaño z test', z_test.shape)
# Out:
# tamaño X train_scaled (5999, 4)
# tamaño y train (5999, 40)
# tamaño z train (5999, 40)
# tamaño X val_scaled (2000, 4)
# tamaño y val (2000, 40)
# tamaño z val_scaled (2000, 40)
# tamaño X test_scaled (2000, 4)
# tamaño y test (2000, 40)
# tamaño z test (2000, 40)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

# Definir callbacks
callbacks = [
    #ModelCheckpoint(filepath='modelo_ep{epoch:02d}_loss{val_loss:.4f}.h5',
    #                monitor='val_loss',
    #                save_best_only=True,
    #                mode='min',
    #                save_weights_only=True,
    #                verbose=1),
    EarlyStopping(monitor='val_loss',
                  patience=4,
                  verbose=1)
]

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding

# Definir dimension de entrada para el encoder
encoder_inputs = Input(shape=(1, 4))

# Capa LSTM  en el encoder
encoder_lstm = LSTM(256, return_state=True)
encoder_output, state_h, state_c = encoder_lstm(encoder_inputs)

# Se descartan las salidas del encoder y solo se toman los estados
encoder_states = [state_h, state_c]

# %%
# Definir dimension de entrada para el decoder
decoder_inputs = Input(shape=(None,))

# Capa de embedding en el decoder
decoder_embedding = Embedding(max_len, output_dim=50)
decoder_inputs_embedded = decoder_embedding(decoder_inputs)

# Capa LSTM 1 en el decoder, con los estados del encoder como inicialización
decoder_lstm1 = LSTM(256, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm1(decoder_inputs_embedded, initial_state=encoder_states)

# Capa densa con activación softmax en el output
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Definir modelo encoder-decoder
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compilar el modelo
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

# %%
history = model.fit([X_train_scaled.reshape(X_train_scaled.shape[0],1,4), z_train], 
    y_train_tokenized.reshape(y_train_tokenized.shape[0], y_train_tokenized.shape[1], 1),
     batch_size=64, 
     epochs=200, 
     validation_data=([X_val_scaled.reshape(X_val.shape[0],1,4), z_val], y_val_tokenized.reshape(y_val_tokenized.shape[0], y_val_tokenized.shape[1], 1)))

loss = history.history['loss']
val_loss = history.history['val_loss']
# Out:
# Epoch 1/200
# 94/94 [==============================] - 12s 20ms/step - loss: 3.1257 - val_loss: 2.7279
# Epoch 2/200
# 94/94 [==============================] - 1s 9ms/step - loss: 2.5538 - val_loss: 2.4565
# Epoch 3/200
# 94/94 [==============================] - 1s 9ms/step - loss: 2.3382 - val_loss: 2.2601
# Epoch 4/200
# 94/94 [==============================] - 1s 11ms/step - loss: 2.1588 - val_loss: 2.1020
# Epoch 5/200
# 94/94 [==============================] - 1s 9ms/step - loss: 1.9625 - val_loss: 1.8795
# Epoch 6/200
# 94/94 [==============================] - 1s 9ms/step - loss: 1.7976 - val_loss: 1.7226
# Epoch 7/200
# 94/94 [==============================] - 1s 10ms/step - loss: 1.7028 - val_loss: 1.6301
# Epoch 8/200
# 94/94 [==============================] - 1s 9ms/step - loss: 1.5698 - val_loss: 1.5667
# Epoch 9/200
# 94/94 [==============================] - 1s 9ms/step - loss: 1.5017 - val_loss: 1.4789
# Epoch 10/200
# 94/94 [==============================] - 1s 9ms/step - loss: 1.4309 - val_loss: 1.4120
# Epoch 11/200
# 94/94 [==============================] - 1s 12ms/step - loss: 1.3725 - val_loss: 1.3554
# Epoch 12/200
# 94/94 [==============================] - 1s 12ms/step - loss: 1.3280 - val_loss: 1.3014
# Epoch 13/200
# 94/94 [==============================] - 1s 14ms/step - loss: 1.2772 - val_loss: 1.2756
# Epoch 14/200
# 94/94 [==============================] - 1s 11ms/step - loss: 1.2411 - val_loss: 1.2291
# Epoch 15/200
# 94/94 [==============================] - 1s 9ms/step - loss: 1.2106 - val_loss: 1.2047
# Epoch 16/200
# 94/94 [==============================] - 1s 9ms/step - loss: 1.1751 - val_loss: 1.1699
# Epoch 17/200
# 94/94 [==============================] - 1s 9ms/step - loss: 1.1468 - val_loss: 1.1476
# Epoch 18/200
# 94/94 [==============================] - 1s 9ms/step - loss: 1.1242 - val_loss: 1.1532
# Epoch 19/200
# 94/94 [==============================] - 1s 11ms/step - loss: 1.1019 - val_loss: 1.0971
# Epoch 20/200
# 94/94 [==============================] - 1s 13ms/step - loss: 1.0797 - val_loss: 1.1021
# Epoch 21/200
# 94/94 [==============================] - 1s 12ms/step - loss: 1.0621 - val_loss: 1.0736
# Epoch 22/200
# 94/94 [==============================] - 1s 10ms/step - loss: 1.0899 - val_loss: 1.1379
# Epoch 23/200
# 94/94 [==============================] - 1s 10ms/step - loss: 1.1126 - val_loss: 1.0594
# Epoch 24/200
# 94/94 [==============================] - 1s 10ms/step - loss: 1.0295 - val_loss: 1.0278
# Epoch 25/200
# 94/94 [==============================] - 1s 13ms/step - loss: 1.0106 - val_loss: 1.0144
# Epoch 26/200
# 94/94 [==============================] - 1s 14ms/step - loss: 1.0019 - val_loss: 1.0038
# Epoch 27/200
# 94/94 [==============================] - 1s 13ms/step - loss: 0.9914 - val_loss: 1.0003
# Epoch 28/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.
200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8991 - val_loss: 0.9115
# Epoch 163/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8976 - val_loss: 0.9083
# Epoch 164/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8972 - val_loss: 0.9118
# Epoch 165/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8971 - val_loss: 0.9114
# Epoch 166/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8982 - val_loss: 0.9093
# Epoch 167/200
# 94/94 [==============================] - 1s 10ms/step - loss: 0.8989 - val_loss: 0.9067
# Epoch 168/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8975 - val_loss: 0.9106
# Epoch 169/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8983 - val_loss: 0.9072
# Epoch 170/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8976 - val_loss: 0.9099
# Epoch 171/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8982 - val_loss: 0.9121
# Epoch 172/200
# 94/94 [==============================] - 1s 10ms/step - loss: 0.8987 - val_loss: 0.9077
# Epoch 173/200
# 94/94 [==============================] - 1s 13ms/step - loss: 0.8979 - val_loss: 0.9078
# Epoch 174/200
# 94/94 [==============================] - 1s 13ms/step - loss: 0.8971 - val_loss: 0.9057
# Epoch 175/200
# 94/94 [==============================] - 1s 13ms/step - loss: 1.0705 - val_loss: 0.9445
# Epoch 176/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.9080 - val_loss: 0.9123
# Epoch 177/200
# 94/94 [==============================] - 1s 10ms/step - loss: 0.9019 - val_loss: 0.9064
# Epoch 178/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.9005 - val_loss: 0.9113
# Epoch 179/200
# 94/94 [==============================] - 1s 10ms/step - loss: 0.8989 - val_loss: 0.9077
# Epoch 180/200
# 94/94 [==============================] - 1s 10ms/step - loss: 0.8980 - val_loss: 0.9093
# Epoch 181/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8978 - val_loss: 0.9128
# Epoch 182/200
# 94/94 [==============================] - 1s 10ms/step - loss: 0.8980 - val_loss: 0.9109
# Epoch 183/200
# 94/94 [==============================] - 1s 10ms/step - loss: 0.8976 - val_loss: 0.9115
# Epoch 184/200
# 94/94 [==============================] - 1s 10ms/step - loss: 0.8972 - val_loss: 0.9083
# Epoch 185/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8981 - val_loss: 0.9100
# Epoch 186/200
# 94/94 [==============================] - 1s 11ms/step - loss: 0.8974 - val_loss: 0.9100
# Epoch 187/200
# 94/94 [==============================] - 1s 13ms/step - loss: 0.8975 - val_loss: 0.9085
# Epoch 188/200
# 94/94 [==============================] - 1s 14ms/step - loss: 0.8968 - val_loss: 0.9115
# Epoch 189/200
# 94/94 [==============================] - 1s 12ms/step - loss: 0.8974 - val_loss: 0.9088
# Epoch 190/200
# 94/94 [==============================] - 1s 10ms/step - loss: 0.8973 - val_loss: 0.9077
# Epoch 191/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8958 - val_loss: 0.9111
# Epoch 192/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8961 - val_loss: 0.9086
# Epoch 193/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8969 - val_loss: 0.9087
# Epoch 194/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8954 - val_loss: 0.9083
# Epoch 195/200
# 94/94 [==============================] - 1s 10ms/step - loss: 0.8975 - val_loss: 0.9112
# Epoch 196/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8970 - val_loss: 0.9105
# Epoch 197/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8965 - val_loss: 0.9078
# Epoch 198/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8972 - val_loss: 0.9096
# Epoch 199/200
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8965 - val_loss: 0.9065
# Epoch 200/200
# 94/94 [==============================] - 1s 10ms/step - loss: 0.8956 - val_loss: 0.9085

# %%
import matplotlib.pyplot as plt

# Crear el gráfico
plt.figure(figsize=(12, 8))
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, color='r', label='Training loss')
plt.plot(epochs, val_loss, color='g', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.evaluate([X_test.reshape(X_test.shape[0],1,4),z_test])
# Out:
# 63/63 [==============================] - 1s 2ms/step - loss: 0.0000e+00
# 0.0

# %%
def predictions(preds):
    preds_words = []
    for i in range(preds.shape[0]):
        preds_row = preds[i]
        preds_row_words = []
        for idx in preds_row:
            if idx in tokenizer.index_word:
                preds_row_words.append(tokenizer.index_word[idx])
        preds_words.append(preds_row_words)

    return preds_words

# %%
preds = model.predict([X_test.reshape(X_test.shape[0],1,4), z_test])
# Out:
# 63/63 [==============================] - 1s 5ms/step

# %%
preds = np.argmax(preds, axis=-1)

# %%
frasesnlg = predictions(preds)
print(frasesnlg)
# Out:
# [['cuando', 'caso', 'de', 'la', 'pared', 'que', 'la', 'te', 'estás', 'alejando', 'de', 'la', 'la', 'gira', 'tu', 'muy', 'lento', 'rápidamente', 'hacia', 'delante', 'rápidamente', 'hacia', 'adelante', 'rueda', 'rápidamente', 'derecha', 'lento', 'muy', 'lento'], ['cuando', 'te', 'encuentres', 'muy', 'cerca', 'a', 'la', 'pared', 'no', 'acercarte', 'ni', 'alejándote', 'ni', 'te', 'despacito', 'la', 'rueda', 'gira', 'hacia', 'rueda', 'despacito', 'la', 'rueda', 'atrás', 'y', 'la', 'y', 'la', 'rueda', 'derecha', 'hacia', 'atrás'], ['cuando', 'encuentres', 'encuentres', 'cerca', 'a', 'la', 'la', 'pero', 'no', 'te', 'ni', 'alejándote', 'ella', 'te', 'alejas', 'necesario', 'rueda', 'izquierda', 'tu', 'rueda', 'despacito', 'la', 'rueda', 'atrás', 'y', 'la', 'y', 'la', 'rueda', 'derecha', 'hacia', 'atrás'], ['estés', 'te', 'de', 'que', 'de', 'la', 'pared', 'y', 'te', 'estás', 'alejas', 'de', 'ella', 'girar', 'ella', 'tu', 'rueda', 'izquierda', 'hacia', 'hacia', 'y', 'y', 'gira', 'tu', 'rueda', 'derecha', 'derecha', 'hacia', 'atrás'], ['cuando', 'caso', 'de', 'la', 'pared', 'que', 'la', 'te', 'estás', 'alejando', 'de', 'la', 'pared', 'gira', 'tu', 'rueda', 'rueda', 'izquierda', 'rueda', 'hacia', 'delante', 'y', 'gira', 'tu', 'rápidamente', 'derecha', 'derecha', 'muy'], ['cuando', 'estás', 'encuentras', 'cerca', 'a', 'la', 'pared', 'pared', 'no', 'acercarte', 'ni', 'alejándote', 'ni', 'te', 'despacito', 'la', 'rueda', 'gira', 'tu', 'rueda', 'despacito', 'la', 'rueda', 'atrás', 'y', 'la', 'y', 'la', 'rueda', 'derecha', 'hacia', 'atrás'], ['cuando', 'te', 'de', 'la', 'te', 'estás', 'es', 'la', 'estás', 'acercando', 'a', 'distancia', 'rueda', 'gira', 'tu', 'rueda', 'izquierda', 'muy', 'lento', 'hacia', 'atrás', 'mientras', 'gira', 'tu', 'rueda', 'derecha', 'rápidamente', 'hacia'], ['cuando', 'estás', 'encuentres', 'cerca', 'a', 'la', 'la', 'pero', 'ni', 'te', 'ni', 'más', 'ella', 'te', 'alejas', 'de', 'ella', 'debes', 'girar', 'rueda', 'la', 'rueda', 'atrás', 'y', 'la', 'y', 'la', 'rueda', 'derecha', 'hacia', 'atrás'], ['cuando', 'caso', 'de', 'la', 'pared', 'y', 'estás', 'te', 'estás', 'alejando', 'de', 'la', 'pared', 'gira', 'tu', 'rueda', 'izquierda', 'rápidamente', 'hacia', 'delante', 'rápidamente', 'hacia', 'adelante', 'rueda', 'derecha', 'muy', 'lento', 'muy', 'lento'], ['cuando', 'caso', 'de', 'acercando', 'te', 'acercando', 'pero', 'pero', 'estás', 'acercando', 'acercando', 'tu', 'gira', 'tu', 'rueda', 'izquierda', 'izquierda', 'lento', 'hacia', 'hacia', 'y', 'y', 'la', 'rueda', 'derecha', 'hacia'], ['estés', 'estás', 'de', 'de', 'la', 'pared', 'pared', 'te', 'estás', 'y', 'de', 'ella', 'ella', 'gira', 'tu', 'rueda', 'izquierda', 'muy', 'rápido', 'bastante', 'delante', 'y', 'tu', 'rueda', 'derecha', 'derecha', 'despacito', 'hacia', 'atrás'], ['cuando', 'estás', 'cerca', 'a', 'la', 'pared', 'y', 'te', 'cerca', 'de', 'ella', 'ella', 'debes', 'girar', 'tu', 'rueda', 'izquierda', 'muy', 'rápido', 'hacia', 'atrás', 'y', 'gira', 'tu', 'derecha', 'muy', 'rápido', 'rápido', 'adelante'], ['en', 'estás', 'a', 'la', 'la', 'y', 'te', 'estás', 'acercando', 'distancia', 'a', 'ella', 'girar', 'tu', 'rueda', 'izquierda', 'muy', 'rápido', 'hacia', 'atrás', 'y', 'gira', 'tu', 'derecha', 'muy', 'rápido', 'rápido', 'adelante'], ['estés', 'te', 'de', 'que', 'de', 'la', 'pared', 'y', 'te', 'estás', 'alejas', 'de', 'ella', 'girar', 'ella', 'tu', 'rueda', 'izquierda', 'hacia', 'hacia', 'y', 'y', 'gira', 'tu', 'rueda', 'derecha', 'derecha', 'hacia', 'atrás'], ['cuando', 'te', 'encuentres', 'cerca', 'cerca', 'la', 'la', 'pared', 'no', 'ni', 'ni', 'alejarte', 'ella', 'te', 'despacito', 'la', 'rueda', 'gira', 'hacia', 'rueda', 'despacito', 'la', 'rueda', 'atrás', 'y', 'la', 'y', 'la', 'rueda', 'derecha', 'hacia', 'atrás'], ['cuando', 'estás', 'cerca', 'a', 'la', 'pared', 'y', 'te', 'cerca', 'la', 'ella', 'ella', 'debes', 'girar', 'tu', 'rueda', 'izquierda', 'muy', 'rápido', 'hacia', 'atrás', 'y', 'gira', 'tu', 'derecha', 'muy', 'rápido', 'rápido', 'adelante'], [ ...

# %% [markdown]
# # guardar el modelo y cargarlo despues

# %%
# Guarda el modelo
model.save('/content/drive/MyDrive/UBA/Trabajo de grado/Modelos/NLG_GeNeSys_vocab_limi.h5')

# %%
X_test[0]
# Out:
# array([ 2.99085678e-02, -2.41957776e-01,  5.47191753e+01, -4.59531379e+00])

# %%
entrada = model.layers[0](X_test[0].reshape(1,1,4)) ##capa input

# %%
encod_in = model.layers[3](entrada)## entrada enncoder

# %%
dec_in = model.layers[1](z_test[0])## capa input decoder

# %%
dec_emb = model.layers[2](dec_in) #capa embeding decoder

# %%
enc_out = model.layers[4](tf.expand_dims(dec_emb, axis=0),initial_state=[encod_in[1],encod_in[2]])

# %%
dense_out = model.layers[5](enc_out[0])

# %%
maxs = np.argmax(dense_out, axis=-1)

# %%
print(predictions(maxs))
# Out:
# [['cuando', 'caso', 'de', 'la', 'pared', 'que', 'la', 'te', 'estás', 'alejando', 'de', 'la', 'la', 'gira', 'tu', 'muy', 'lento', 'rápidamente', 'hacia', 'delante', 'rápidamente', 'hacia', 'adelante', 'rueda', 'rápidamente', 'derecha', 'lento', 'muy', 'lento']]
